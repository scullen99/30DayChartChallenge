# %% [markdown]
# # Day 12
#
# Source: https://www.kaggle.com/datasets/fredericksalazar/pib-gdp-global-by-countries-since-1960-to-2021?select=countries_gdp_hist.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('countries_gdp_hist.csv', delimiter=';')
df.shape
# Out:
# (13330, 10)

# %%
df.sample(10)
# Out:
#       country_code region_name                  sub_region_name  \
# 7240           LVA      Europe                  Northern Europe
# 1647           BRA    Americas  Latin America and the Caribbean
# 5996           JOR        Asia                     Western Asia
# 1024           BFA      Africa               Sub-Saharan Africa
# 8256           MOZ      Africa               Sub-Saharan Africa
# 5084           HND    Americas  Latin America and the Caribbean
# 5445           IMN      Europe                  Northern Europe
# 1424           BLR      Europe                   Eastern Europe
# 1131           BGR      Europe                   Eastern Europe
# 13214          ZMB      Africa               Sub-Saharan Africa
#
#       intermediate_region  country_name                    income_group  year  \
# 7240              no data        Latvia                    Ingreso alto  2008
# 1647        South America        Brazil            Ingreso mediano alto  1995
# ...

# %%
df.drop(columns=['country_code', 'region_name', 'sub_region_name', 'intermediate_region'], inplace=True)
df.shape
